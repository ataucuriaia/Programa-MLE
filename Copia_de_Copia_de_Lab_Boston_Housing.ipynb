# %% [markdown]
# <a href="https://colab.research.google.com/github/ataucuriaia/Programa-MLE/blob/main/Copia_de_Copia_de_Lab_Boston_Housing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1 align=center><font size = 5>Boston Housing</font></h1>
#
# ---

# %% [markdown]
# ## Introducción

# %% [markdown]
# En este laboratorio, aprenderá a usar python para construir un modelo de regresión.

# %% [markdown]
# <h3>Objetivo de este Notebook<h3>
# <h5> 1. Como construir e interpretar un modelo de regresión.</h5>
# <h5> 2. Descargar y limpiar un Dataset </h5>
# <h5> 3. Realizar los pasos necesarios previos a la etapa de modelamiento </h5>
# <h5> 4. Entrenar y Testear modelo </h5>

# %% [markdown]
# ## Tabla de Contenidos
#
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#
# <font size = 3>
#
# 1. <a href="#item31">Importar Librerías</a>
# 2. <a href="#item32">Descargar y limpiar el Dataset</a>
# 3. <a href="#item33">Pre-selección de variables</a>
# 4. <a href="#item33">Preparación de datos</a>
# 5. <a href="#item33">Construir un modelo de regresión lineal</a>
# 6. <a href="#item34">Entrenar y Testear el modelo</a>
#
# </font>
# </div>

# %% [markdown]
# ## Descargar y limpiar Dataset

# %% [markdown]
# Primero, importemos algunos módulos comunes, asegurémonos de que MatplotLib tenga una configuración adecuada para el tamaño de nuestros gráficos. También verificamos que Python 3.5 o posterior esté instalado (aunque Python 2.x puede funcionar, está obsoleto), así como Scikit-Learn ≥0.20.

# %%
# Scikit-Learn 
import sklearn

# Imports comunes
import pandas as pd
import numpy as np
import os

# Configuración de tamaño de gráficos matplotlib
# %matplotlib inline
import matplotlib as mpl
import matplotlib.pyplot as plt

mpl.rc('axes', labelsize=14)
mpl.rc('xtick', labelsize=12)
mpl.rc('ytick', labelsize=12)

# Cargar seaborn 
import seaborn as sns
sns.set(style="whitegrid", color_codes = True)
sns.set(rc={'figure.figsize':(10,6)})

# Ignore las advertencias poco útiles
import warnings
warnings.filterwarnings(action="ignore", message="^internal gelsd")

# %% [markdown]
# <b>Valores de la vivienda en los suburbios de Boston</b>
#
# <h5>La variable <b>medv</b> es la variable objetivo.</h5>
#
# <b>Descripción de datos</b>
#
# El data frame de Boston tiene 506 filas y 14 columnas.
#
# <b>Este data frame contiene las siguientes columnas:</b>
#
# ---
#
# * <b>crim : </b> Tasa de criminalidad per cápita por ciudad.
#
# * <b>zn : </b> Proporción de terreno residencial dividido en zonas para lotes de más de 25,000 pies cuadrados.
#
# * <b>indus : </b> Proporción de acres comerciales no minoristas por ciudad.
#
# * <b>chas : </b> Variable ficticia de Charles River (= 1 si el tramo limita con el río; 0 en caso contrario).
#
# * <b>nox : </b>Concentración de óxidos de nitrógeno (partes por 10 millones).
#
# * <b>rm : </b>Número medio de habitaciones por vivienda.
#
# * <b>años : </b> Proporción de unidades ocupadas por sus propietarios construidas antes de 1940.
#
# * <b>dis : </b>Media ponderada de las distancias a cinco centros de empleo de Boston.
#
# * <b>rad : </b>Indice de accesibilidad a carreteras radiales.
#
# * <b>impuesto : </b>Tasa de impuesto a la propiedad de valor total por \$ 10,000.
#
# * <b>ptratio : </b>Proporción alumno-profesor por ciudad.
#
# * <b>black : </b> 1000 (Bk - 0.63) ^ 2 donde Bk es la proporción de negros por ciudad.
#
# * <b>lstat : </b>Estatus más bajo de la población (porcentaje).
#
# * <b>medv : </b>Valor medio de las viviendas ocupadas por sus propietarios en \$ 1000.
#
# ---
#
# <strong>Puede consultar este [link](https://kaggle.com/c/boston-housing) para leer más sobre la fuente de datos boston housing.</strong>
#
# <strong>Puede descargar la data en este [link](https://www.kaggle.com/datasets/altavish/boston-housing-dataset)</strong>

# %% [markdown]
# ## 1. Leyendo y Explorando data

# %%
#cargamos la data

pddf = pd.read_csv('HousingData 2.csv')

# %%
pddf.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
pddf.shape
# Out:
# (506, 14)

# %%
# Vamos a describir la información
pddf.describe().transpose()
# Out:
#          count        mean         std        min         25%         50%  \
# CRIM     486.0    3.611874    8.720192    0.00632    0.081900    0.253715
# ZN       486.0   11.211934   23.388876    0.00000    0.000000    0.000000
# INDUS    486.0   11.083992    6.835896    0.46000    5.190000    9.690000
# CHAS     486.0    0.069959    0.255340    0.00000    0.000000    0.000000
# NOX      506.0    0.554695    0.115878    0.38500    0.449000    0.538000
# RM       506.0    6.284634    0.702617    3.56100    5.885500    6.208500
# AGE      486.0   68.518519   27.999513    2.90000   45.175000   76.800000
# DIS      506.0    3.795043    2.105710    1.12960    2.100175    3.207450
# RAD      506.0    9.549407    8.707259    1.00000    4.000000    5.000000
# TAX      506.0  408.237154  168.537116  187.00000  279.000000  330.000000
# PTRATIO  506.0   18.455534    2.164946   12.60000   17.400000   19.050000
# B        506.0  356.674032   91.294864    0.32000  375.377500  391.440000
# LSTAT    486.0   12.715432    7.155871    1.73000    7.125000   11.430000
# MEDV     506.0   22.532806    9.197104    5.00000   17.025000   21.200000
#
#                 75%       max
# CRIM       3.560263   88.9762
# ZN        12.500000  100.0000
# INDUS     18.100000   27.7400
# CHAS       0.000000    1.0000
# NOX        0.624000    0.8710
# RM         6.623500    8.7800
# AGE       93.975000  100.0000
# DIS        5.188425   12.1265
# RAD       24.000000   24.0000
# TAX      666.000000  711.0000
# PTRATIO   20.200000   22.0000
# B        396.225000  396.9000
# LSTAT     16.955000   37.9700
# MEDV      25.000000   50.0000

# %%
# Gráfico de distribución 
import seaborn as sns
sns.displot(pddf.ZN, kind="kde", fill=True)

# %%
#Boxplot
sns.set_theme(style="whitegrid")
ax = sns.boxplot(data=pddf.NOX, orient="v")
ax = sns.swarmplot(data=pddf.NOX, color=".25")

# %%
sns.displot(pddf.MEDV, kind="kde", fill=True)

# %%
sns.set_theme(style="whitegrid")
ax = sns.boxplot(data=pddf.MEDV, orient="v")
ax = sns.swarmplot(data=pddf.MEDV, color=".25")

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
pddf.hist(bins=50, figsize=(20,15))
plt.show()

# %% [markdown]
# ## 2. Selección de muestras

# %%
pddf.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
# Shuffle the data
from sklearn.utils import shuffle
pddf = shuffle(pddf, random_state = 123)

# %%
# Elección de variables
features = list(set(pddf.columns.tolist()) - set(['MEDV']))
features
# Out:
# ['AGE',
#  'B',
#  'RAD',
#  'PTRATIO',
#  'LSTAT',
#  'TAX',
#  'CRIM',
#  'ZN',
#  'NOX',
#  'RM',
#  'CHAS',
#  'INDUS',
#  'DIS']

# %%
# Definiendo data
X = pddf[features]
y = pddf.MEDV

# %%
# Muestreo

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    train_size = 0.7, 
                                                    random_state = 123)

# %%
print(X.shape)
print(X_train.shape)
print(X_test.shape)
# Out:
# (506, 13)
# (354, 13)
# (152, 13)

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (10,6)

plt.scatter(X_train.NOX, y_train)
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
# Out:
# Text(0, 0.5, '$y$')

# %%
plt.scatter(X_train.NOX, y_train, alpha = 0.5)
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.show()

# %%
# Matriz de scatterplots
from pandas.plotting import scatter_matrix
scatter_matrix(X_train, figsize=(30, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f3068867a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30687fac90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30687b92d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30687ed8d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30687a4ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306886be10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306892fe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30688b3210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068947150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068713e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068684550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068645fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30685fd190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f30685b4790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30685ead90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30685af3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30685659d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068529050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30684df610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068495c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068459250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068410850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30683c8e50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306838b490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068342a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30683060d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f30682bd6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068273cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068235310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306826c910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068222f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30681e9550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30681aafd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068163190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068119790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30680d47d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068089cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306804e210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068004710>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3067fbac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067f7e150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067f35650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067ef7fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067f2e090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067ee3590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067e9ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067e52f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067e164d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067dce9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067d83ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067d46410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067cfd910>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3067cb4e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067c76350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067cae850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067c65d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067c26290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067bdc790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067b93c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067b591d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067b0d6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067ac4bd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306887b9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068614890>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30684ad4d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f30682d56d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068156550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306798e710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067945d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067908350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30678bf950>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067875f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306783a5d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306786fbd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30677b2210>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30677e9810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306779fe10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067763450>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f306771ba50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30676e0090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067695690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306764cc90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30676102d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30675c48d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306757ced0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306753f510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30674f7b10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30674bc150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067472750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30674a8d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306746c390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3067422990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30673de990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067394e90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306735a3d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30673108d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30672c5dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067289310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306723f810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30671f3d10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30671ba250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30671ef750>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30671a8c50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306716a190>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3067120690>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30670d7b90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30670990d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30670515d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067007ad0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066fcb050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066f81510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066f38a10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066f6ff10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066eb1450>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066ee9990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066e9fe90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066e623d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3066e178d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066dd0dd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3068438910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30678dd590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067741f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30675e68d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3067409310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066c969d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066c5d050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066c12610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066bcac10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066b8e250>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066b45850>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3066afbe50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066abe490>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066a76a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066a380d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30669f06d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066a27cd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30669eb310>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306699f910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066958f10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306691b550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30668ddfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066897190>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306684e790>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3066805d90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30667c63d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306677e9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066742050>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30666f7610>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306672fc10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066674fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30666ae090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066665590>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306661ba90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30665d1f90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30665944d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306654d9d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7f3066504ed0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30664c6410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306647d910>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066434e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30663f6350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306642c850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30663e5d50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30663a8290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306635c790>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066313c90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f30662d71d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f306628e6d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f3066245bd0>]],
#       dtype=object)

# %% [markdown]
# ## 3. Pre-selección de variables

# %%
# Dando formato a nuestra tabla resumen

pdResume = X_train.describe().transpose()
pdResume.reset_index(inplace = True)
pdResume.rename(columns = {'index' : 'feature',
                           '25%' : 'Q1',
                           '50%' : 'median',
                           '75%' : 'Q3'}, inplace = True)

# %%
pdResume[['missing_rate']] = 1 - pdResume[['count']]/X_train.shape[0]
pdResume.sort_values(by = 'missing_rate', ascending = False, inplace = True)

# %%
# Calculando las correlaciones de todas las variables con el target

temp = X_train.copy()
temp['target'] = y_train

correlations = []
for col in features:
  correlations.append(temp[[col, 'target']].corr().iloc[0][1])

# %%
# Cruzando correlaciones con la tabla de resumen original

pdres_cor = pd.DataFrame({'feature' : features, 'corr_MEDV' : correlations})
pdResume2 = pd.merge(pdResume, pdres_cor, on = 'feature')

# %%
pdResume2['abs_corr_MEDV'] = pdResume2.corr_MEDV.apply(lambda x: abs(x))
pdResume2.sort_values(by = 'abs_corr_MEDV', ascending = False, inplace=True)

pdResume2.head()
# Out:
#     feature  count        mean         std      min         Q1   median  \
# 11       RM  354.0    6.276766    0.705929    3.561    5.87825    6.185
# 2     LSTAT  339.0   12.945015    7.195009    1.730    7.43500   11.740
# 8   PTRATIO  354.0   18.375706    2.194308   12.600   17.00000   18.800
# 9       TAX  354.0  402.813559  167.121147  187.000  277.00000  330.000
# 0     INDUS  338.0   11.082751    6.868390    0.460    5.13000    9.690
#
#            Q3      max  missing_rate  corr_MEDV  abs_corr_MEDV
# 11    6.60175    8.725      0.000000   0.763989       0.763989
# 2    17.10000   36.980      0.042373  -0.751647       0.751647
# 8    20.20000   21.200      0.000000  -0.561413       0.561413
# 9   666.00000  711.000      0.000000  -0.523892       0.523892
# 0    18.10000   27.740      0.045198  -0.512475       0.512475

# %%
# Guardando resultados
pdResume2.to_csv('univariate_assesment.csv', index = 0)

# %%
plt.scatter(X_train.RM, y_train, alpha = 0.5)
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.show()

# %%
plt.scatter(X_train.LSTAT, y_train, alpha = 0.5)
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.show()

# %%
sns.regplot(X_train.LSTAT, y_train, scatter_kws={'alpha':0.5})
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.regplot(X_train.PTRATIO, y_train, scatter_kws={'alpha':0.5})
plt.xlabel("$x_1$", fontsize=18)
plt.ylabel("$y$", rotation=0, fontsize=18)
plt.show()

# %% [markdown]
# ## 4. Preparación de datos

# %% [markdown]
# <h3>Tratamiento de outliers</h3>

# %% [markdown]
# ### Outliers por Rango Intercuantílico

# %% [markdown]
# <img src="https://miro.medium.com/max/1400/1*2c21SkzJMf3frPXPAR_gZA.png" width="500"
#      height="300" >

# %% [markdown]
# <img src="data:image/png;base64,..." width="450"
#      height="150" >

# %%
#Leyendo tabla resumen

univariate_II = pd.read_csv('univariate_assesment.csv')
univariate_II.head()
# Out:
#    feature  count        mean         std      min         Q1   median  \
# 0       RM  354.0    6.276766    0.705929    3.561    5.87825    6.185
# 1    LSTAT  339.0   12.945015    7.195009    1.730    7.43500   11.740
# 2  PTRATIO  354.0   18.375706    2.194308   12.600   17.00000   18.800
# 3      TAX  354.0  402.813559  167.121147  187.000  277.00000  330.000
# 4    INDUS  338.0   11.082751    6.868390    0.460    5.13000    9.690
#
#           Q3      max  missing_rate  corr_MEDV  abs_corr_MEDV
# 0    6.60175    8.725      0.000000   0.763989       0.763989
# 1   17.10000   36.980      0.042373  -0.751647       0.751647
# 2   20.20000   21.200      0.000000  -0.561413       0.561413
# 3  666.00000  711.000      0.000000  -0.523892       0.523892
# 4   18.10000   27.740      0.045198  -0.512475       0.512475

# %%
# Calculando los intervalos RIC

univariate_II['ric'] = univariate_II['Q3'] - univariate_II['Q1']

univariate_II['min_ric'] = univariate_II['Q1'] - 1.5*univariate_II['ric']
univariate_II['max_ric'] = univariate_II['Q3'] + 1.5*univariate_II['ric']

univariate_II.head()
# Out:
#    feature  count        mean         std      min         Q1   median  \
# 0       RM  354.0    6.276766    0.705929    3.561    5.87825    6.185
# 1    LSTAT  339.0   12.945015    7.195009    1.730    7.43500   11.740
# 2  PTRATIO  354.0   18.375706    2.194308   12.600   17.00000   18.800
# 3      TAX  354.0  402.813559  167.121147  187.000  277.00000  330.000
# 4    INDUS  338.0   11.082751    6.868390    0.460    5.13000    9.690
#
#           Q3      max  missing_rate  corr_MEDV  abs_corr_MEDV       ric  \
# 0    6.60175    8.725      0.000000   0.763989       0.763989    0.7235
# 1   17.10000   36.980      0.042373  -0.751647       0.751647    9.6650
# 2   20.20000   21.200      0.000000  -0.561413       0.561413    3.2000
# 3  666.00000  711.000      0.000000  -0.523892       0.523892  389.0000
# 4   18.10000   27.740      0.045198  -0.512475       0.512475   12.9700
#
#     min_ric    max_ric
# 0    4.7930     7.6870
# 1   -7.0625    31.5975
# 2   12.2000    25.0000
# 3 -306.5000  1249.5000
# 4  -14.3250    37.5550

# %%
# Tratamiento de outliers por RIC

for col in univariate_II.feature.tolist():
  desc = univariate_II.loc[univariate_II.feature == col]
  X_train[col + '_tric'] = X_train[col].apply(lambda x: desc.max_ric.values[0] if x > desc.max_ric.values[0]
                                                   else desc.min_ric.values[0] if x < desc.min_ric.values[0]
                                                   else x)

X_train.head()
# Out:
#      TAX      CRIM       B  CHAS     DIS  RAD  LSTAT    NOX   AGE  PTRATIO  \
# 385  666  16.81180  396.90   0.0  1.4261   24  30.81  0.700  98.1     20.2
# 13   307   0.62976  396.90   0.0  4.7075    4   8.26  0.538  61.8     21.0
# 221  307   0.40771  395.24   1.0  3.0480    8  21.46  0.507  91.3     17.4
# 290  245   0.03502  396.90   0.0  5.1167    4   3.33  0.411  27.9     19.2
# 193  265   0.02187  393.37   0.0  6.2196    1   5.03  0.401   NaN     15.6
#
#      ...  TAX_tric  INDUS_tric  RAD_tric  NOX_tric  CRIM_tric  AGE_tric  \
# 385  ...       666       18.10        24     0.700   8.580061      98.1
# 13   ...       307        8.14         4     0.538   0.629760      61.8
# 221  ...       307        6.20         8     0.507   0.407710      91.3
# 290  ...       245        4.95         4     0.411   0.035020      27.9
# 193  ...       265        2.93         1     0.401   0.021870       NaN
#
#      ZN_tric  B_tric  DIS_tric  CHAS_tric
# 385    0.000  396.90    1.4261        0.0
# 13     0.000  396.90    4.7075        0.0
# 221    0.000  395.24    3.0480        0.0
# 290   15.625  396.90    5.1167        0.0
# 193   15.625  393.37    6.2196        0.0
#
# [5 rows x 26 columns]

# %% [markdown]
# Revisemos los resultados

# %%
sns.displot(X_train, x = "CRIM", kind="kde", fill=True)

# %%
sns.displot(X_train, x = "CRIM_tric", kind="kde", fill=True)

# %% [markdown]
# ### Outliers por Z-score

# %% [markdown]
# <img src="https://editor.analyticsvidhya.com/uploads/440971.png" width="500"
#      height="300" >

# %%
univariate_II.head()
# Out:
#    feature  count        mean         std      min         Q1   median  \
# 0       RM  354.0    6.276766    0.705929    3.561    5.87825    6.185
# 1    LSTAT  339.0   12.945015    7.195009    1.730    7.43500   11.740
# 2  PTRATIO  354.0   18.375706    2.194308   12.600   17.00000   18.800
# 3      TAX  354.0  402.813559  167.121147  187.000  277.00000  330.000
# 4    INDUS  338.0   11.082751    6.868390    0.460    5.13000    9.690
#
#           Q3      max  missing_rate  corr_MEDV  abs_corr_MEDV       ric  \
# 0    6.60175    8.725      0.000000   0.763989       0.763989    0.7235
# 1   17.10000   36.980      0.042373  -0.751647       0.751647    9.6650
# 2   20.20000   21.200      0.000000  -0.561413       0.561413    3.2000
# 3  666.00000  711.000      0.000000  -0.523892       0.523892  389.0000
# 4   18.10000   27.740      0.045198  -0.512475       0.512475   12.9700
#
#     min_ric    max_ric
# 0    4.7930     7.6870
# 1   -7.0625    31.5975
# 2   12.2000    25.0000
# 3 -306.5000  1249.5000
# 4  -14.3250    37.5550

# %%
# Calculando los intervalos Z-score

univariate_II['min_zscore'] = univariate_II['mean'] - 3*univariate_II['std']
univariate_II['max_zscore'] = univariate_II['mean'] + 3*univariate_II['std']

univariate_II.head()
# Out:
#    feature  count        mean         std      min         Q1   median  \
# 0       RM  354.0    6.276766    0.705929    3.561    5.87825    6.185
# 1    LSTAT  339.0   12.945015    7.195009    1.730    7.43500   11.740
# 2  PTRATIO  354.0   18.375706    2.194308   12.600   17.00000   18.800
# 3      TAX  354.0  402.813559  167.121147  187.000  277.00000  330.000
# 4    INDUS  338.0   11.082751    6.868390    0.460    5.13000    9.690
#
#           Q3      max  missing_rate  corr_MEDV  abs_corr_MEDV       ric  \
# 0    6.60175    8.725      0.000000   0.763989       0.763989    0.7235
# 1   17.10000   36.980      0.042373  -0.751647       0.751647    9.6650
# 2   20.20000   21.200      0.000000  -0.561413       0.561413    3.2000
# 3  666.00000  711.000      0.000000  -0.523892       0.523892  389.0000
# 4   18.10000   27.740      0.045198  -0.512475       0.512475   12.9700
#
#     min_ric    max_ric  min_zscore  max_zscore
# 0    4.7930     7.6870    4.158979    8.394552
# 1   -7.0625    31.5975   -8.640012   34.530042
# 2   12.2000    25.0000   11.792781   24.958631
# 3 -306.5000  1249.5000  -98.549883  904.177001
# 4  -14.3250    37.5550   -9.522419   31.687922

# %%
# Tratamiento de outliers por Z-score

for col in univariate_II.feature.tolist():
  desc = univariate_II.loc[univariate_II.feature == col]
  X_train[col + '_tzscore'] = X_train[col].apply(lambda x: desc.max_zscore.values[0] if x > desc.max_zscore.values[0]
                                                   else desc.min_zscore.values[0] if x < desc.min_zscore.values[0]
                                                   else x)

X_train.head()
# Out:
#      TAX      CRIM       B  CHAS     DIS  RAD  LSTAT    NOX   AGE  PTRATIO  \
# 385  666  16.81180  396.90   0.0  1.4261   24  30.81  0.700  98.1     20.2
# 13   307   0.62976  396.90   0.0  4.7075    4   8.26  0.538  61.8     21.0
# 221  307   0.40771  395.24   1.0  3.0480    8  21.46  0.507  91.3     17.4
# 290  245   0.03502  396.90   0.0  5.1167    4   3.33  0.411  27.9     19.2
# 193  265   0.02187  393.37   0.0  6.2196    1   5.03  0.401   NaN     15.6
#
#      ...  TAX_tzscore  INDUS_tzscore  RAD_tzscore  NOX_tzscore  CRIM_tzscore  \
# 385  ...          666          18.10           24        0.700      16.81180
# 13   ...          307           8.14            4        0.538       0.62976
# 221  ...          307           6.20            8        0.507       0.40771
# 290  ...          245           4.95            4        0.411       0.03502
# 193  ...          265           2.93            1        0.401       0.02187
#
#      AGE_tzscore  ZN_tzscore  B_tzscore  DIS_tzscore  CHAS_tzscore
# 385         98.1    0.000000     396.90       1.4261      0.000000
# 13          61.8    0.000000     396.90       4.7075      0.000000
# 221         91.3    0.000000     395.24       3.0480      0.891748
# 290         27.9   75.914296     396.90       5.1167      0.000000
# 193          NaN   60.000000     393.37       6.2196      0.000000
#
# [5 rows x 39 columns]

# %% [markdown]
# Revisemos los resultados

# %%
sns.displot(X_train, x = "CRIM", kind="kde", fill=True)

# %%
sns.displot(X_train, x = "CRIM_tzscore", kind="kde", fill=True)

# %%
univariate_II.to_csv('univariate_assesment.csv', index = 0)

# %% [markdown]
# ### Tratamiento de Missings

# %%
all_features = X_train.columns.tolist()

# %%
# Trataiento de missings

X_train[[x + '_imp' for x in all_features]] = X_train[all_features].fillna(X_train[all_features].median())

# %%
X_train[[x + '_imp' for x in all_features]].head(30)
# Out:
#      TAX_imp  CRIM_imp   B_imp  CHAS_imp  DIS_imp  RAD_imp  LSTAT_imp  \
# 385      666  16.81180  396.90       0.0   1.4261       24      30.81
# 13       307   0.62976  396.90       0.0   4.7075        4       8.26
# 221      307   0.40771  395.24       1.0   3.0480        8      21.46
# 290      245   0.03502  396.90       0.0   5.1167        4       3.33
# 193      265   0.02187  393.37       0.0   6.2196        1       5.03
# 435      666  11.16040  109.85       0.0   2.1247       24      23.27
# 339      224   0.05497  396.90       0.0   4.8122        5       9.74
# 172      296   0.13914  396.90       0.0   2.5961        5      14.69
# 230      307   0.53700  378.35       0.0   3.6715        8      11.65
# 334      224   0.03738  389.40       0.0   6.4584        5       6.75
# 328      430   0.06617  382.44       0.0   5.2146        4       9.97
# 51       243   0.04337  393.97       0.0   6.8147        4       9.43
# 213      277   0.14052  385.81       0.0   3.9454        4       9.38
# 352      411   0.07244  392.33       0.0  10.7103        4       7.79
# 394      666   0.25293  396.90       0.0   1.7821       24      16.35
# 100      384   0.14866  394.76       0.0   2.7778        5       9.42
# 5        222   0.02985  394.12       0.0   6.0622        3       5.21
# 310      304   2.63548  350.45       0.0   2.5194        4      12.64
# 297      289   0.14103  396.90       0.0   6.3200        4      15.84
# 197      329   0.04666  354.31       0.0   7.3090        2       8.61
# 207      277   0.25199  389.43       0.0   4.3549        4      11.74
# 124      188   0.09849  379.38       0.0   2.0063        2      17.58
# 61       284   0.17171  378.08       0.0   6.8185        8      14.44
# 264      264   0.55007  387.89       0.0   1.9301        5       8.10
# 420      666  11.08740  318.75       0.0   1.8589       24      15.02
# 182      193   0.09103  394.12       0.0   2.7006        3       4.82
# 356      666   8.98296  377.73       1.0   2.1222       24      17.60
# 130      437   0.34006  395.04       0.0   2.1185        4      12.60
# 128      437   0.32543  396.90       0.0   1.8125        4      15.39
# 491      711   0.10574  390.11       0.0   1.8681        4      18.07
#
#      NOX_imp  AGE_imp  PTRATIO_imp  ...  TAX_tzscore_imp  INDUS_tzscore_imp  \
# 385    0.700     98.1         20.2  ...              666              18.10
# 13     0.538     61.8         21.0  ...              307               8.14
# 221    0.507     91.3         17.4  ...              307               6.20
# 290    0.411     27.9         19.2  ...              245               4.95
# 193    0.401     78.1         15.6  ...              265               2.93
# 435    0.740     94.6         20.2  ...              666              18.10
# 339    0.515     45.4         20.2  ...              224               5.19
# 172    0.510     88.5         16.6  ...              296               4.05
# 230    0.504     68.1         17.4  ...              307               6.20
# 334    0.515     38.5         20.2  ...              224               5.19
# 328    0.460     25.8         16.9  ...              430               3.24
# 51     0.439     63.0         16.8  ...              243               9.69
# 213    0.489     32.3         18.6  ...              277              10.59
# 352    0.411     18.5         18.3  ...              411               1.69
# 394    0.693     94.7         20.2  ...              666              18.10
# 100    0.520     79.9         20.9  ...              384               8.56
# 5      0.458     58.7         18.7  ...              222               2.18
# 310    0.544     37.8         18.4  ...              304               9.90
# 297    0.437     58.0         16.0  ...              289               9.69
# 197    0.404     36.6         12.6  ...              329               1.52
# 207    0.489     72.7         18.6  ...              277              10.59
# 124    0.581     95.8         19.1  ...              188              25.65
# 61     0.453     93.4         19.7  ...              284               5.13
# 264    0.647     91.6         13.0  ...              264               3.97
# 420    0.718    100.0         20.2  ...              666              18.10
# 182    0.488     92.2         17.8  ...              193               2.46
# 356    0.770     97.4         20.2  ...              666              18.10
# 130    0.624     98.9         21.2  ...              437              21.89
# 128    0.624     98.8         21.2  ...              437              21.89
# 491    0.609     98.8         20.1  ...              711              27.74
#
#      RAD_tzscore_imp  NOX_tzscore_imp  CRIM_tzscore_imp  AGE_tzscore_imp  \
# 385               24            0.700          16.81180             98.1
# 13                 4            0.538           0.62976             61.8
# 221                8            0.507           0.40771             91.3
# 290                4            0.411           0.03502             27.9
# 193                1            0.401           0.02187             78.1
# 435               24            0.740          11.16040             94.6
# 339                5            0.515           0.05497             45.4
# 172                5            0.510           0.13914             88.5
# 230                8            0.504           0.53700             68.1
# 334                5            0.515           0.03738             38.5
# 328                4            0.460           0.06617             25.8
# 51                 4            0.439           0.04337             63.0
# 213                4            0.489           0.14052             32.3
# 352                4            0.411           0.07244             18.5
# 394               24            0.693           0.25293             94.7
# 100                5            0.520           0.14866             79.9
# 5                  3            0.458           0.02985             58.7
# 310                4            0.544           2.63548             37.8
# 297                4            0.437           0.14103             58.0
# 197                2            0.404           0.04666             36.6
# 207                4            0.489           0.25199             72.7
# 124                2            0.581           0.09849             95.8
# 61                 8            0.453           0.17171             93.4
# 264                5            0.647           0.55007             91.6
# 420               24            0.718          11.08740            100.0
# 182                3            0.488           0.09103             92.2
# 356               24            0.770           8.98296             97.4
# 130                4            0.624           0.34006             98.9
# 128                4            0.624           0.32543             98.8
# 491                4            0.609           0.10574             98.8
#
#      ZN_tzscore_imp  B_tzscore_imp  DIS_tzscore_imp  CHAS_tzscore_imp
# 385        0.000000         396.90         1.426100          0.000000
# 13         0.000000         396.90         4.707500          0.000000
# 221        0.000000         395.24         3.048000          0.891748
# 290       75.914296         396.90         5.116700          0.000000
# 193       60.000000         393.37         6.219600          0.000000
# 435        0.000000         109.85         2.124700          0.000000
# 339        0.000000         396.90         4.812200          0.000000
# 172        0.000000         396.90         2.596100          0.000000
# 230        0.000000         378.35         3.671500          0.000000
# 334        0.000000         389.40         6.458400          0.000000
# 328        0.000000         382.44         5.214600          0.000000
# 51        21.000000         393.97         6.814700          0.000000
# 213        0.000000         385.81         3.945400          0.000000
# 352       60.000000         392.33         9.804892          0.000000
# 394        0.000000         396.90         1.782100          0.000000
# 100        0.000000         394.76         2.777800          0.000000
# 5          0.000000         394.12         6.062200          0.000000
# 310        0.000000         350.45         2.519400          0.000000
# 297        0.000000         396.90         6.320000          0.000000
# 197       75.914296         354.31         7.309000          0.000000
# 207        0.000000         389.43         4.354900          0.000000
# 124        0.000000         379.38         2.006300          0.000000
# 61        25.000000         378.08         6.818500          0.000000
# 264       20.000000         387.89         1.930100          0.000000
# 420        0.000000         318.75         1.858900          0.000000
# 182        0.000000         394.12         2.700600          0.000000
# 356        0.000000         377.73         2.122200          0.891748
# 130        0.000000         395.04         2.118500          0.000000
# 128        0.000000         396.90         1.812500          0.000000
# 491        0.000000         390.11         1.868100          0.000000
#
# [30 rows x 39 columns]

# %% [markdown]
# ## 5. Modelo de regresión Lineal

# %% [markdown]
# ### Rregresión lineal por máxima verosimilitud

# %%
features_in = [x + '_imp' for x in all_features if ('_tric' in x) and ('CHAS' not in x)]

# %%
# estandarizando las variables para mantener todas en una misma escala
X_train[[x + '_std' for x in features_in]] = (X_train[features_in] - X_train[features_in].mean())/X_train[features_in].std()

# %%
X_train[[x + '_std' for x in features_in]]

# %%
y_train

# %%
import statsmodels.api as sm

# Fit and summarize OLS model
mod = sm.OLS(y_train, 
             sm.add_constant(X_train[[x + '_std' for x in features_in]]))
res = mod.fit()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.780
# Model:                            OLS   Adj. R-squared:                  0.772
# Method:                 Least Squares   F-statistic:                     100.5
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):          4.11e-104
# Time:                        01:35:14   Log-Likelihood:                -1019.3
# No. Observations:                 354   AIC:                             2065.
# Df Residuals:                     341   BIC:                             2115.
# Df Model:                          12
# Covariance Type:            nonrobust
# ========================================================================================
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# const                   22.4605      0.233     96.278      0.000      22.002      22.919
# RM_tric_imp_std          3.8332      0.340     11.282      0.000       3.165       4.502
# LSTAT_tric_imp_std      -2.4011      0.420     -5.718      0.000      -3.227      -1.575
# PTRATIO_tric_imp_std    -2.4610      0.328     -7.496      0.000      -3.107      -1.815
# TAX_tric_imp_std        -1.5258      0.689     -2.216      0.027      -2.880      -0.172
# INDUS_tric_imp_std      -0.2259      0.422     -0.535      0.593      -1.056       0.605
# RAD_tric_imp_std         2.2930      0.787      2.914      0.004       0.745       3.841
# NOX_tric_imp_std        -1.4564      0.490     -2.972      0.003      -2.420      -0.492
# CRIM_tric_imp_std       -1.9343      0.647     -2.991      0.003      -3.206      -0.662
# AGE_tric_imp_std        -0.5681      0.386     -1.471      0.142      -1.328       0.192
# ZN_tric_imp_std          0.0119      0.339      0.035      0.972      -0.654       0.678
# B_tric_imp_std           0.1499      0.264      0.567      0.571      -0.370       0.670
# DIS_tric_imp_std        -2.5550      0.469     -5.449      0.000      -3.477      -1.633
# ==============================================================================
# Omnibus:                       64.743   Durbin-Watson:                   2.020
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              122.744
# Skew:                           0.995   Prob(JB):                     2.22e-27
# Kurtosis:                       5.088   Cond. No.                         10.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
mod = sm.OLS(y_train, sm.add_constant(X_train[['RM_tric_imp_std',
                               'LSTAT_tric_imp_std',
                               #'PTRATIO_tric_imp',
                               'TAX_tric_imp_std',
                               'RAD_tric_imp_std',
                               'CRIM_tric_imp_std',
                               'NOX_tric_imp_std',
                               #'B_tric_imp',
                               'DIS_tric_imp_std']]))
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     135.2
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):           5.65e-95
# Time:                        01:37:31   Log-Likelihood:                -1053.7
# No. Observations:                 354   AIC:                             2123.
# Df Residuals:                     346   BIC:                             2154.
# Df Model:                           7
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 22.4605      0.255     87.995      0.000      21.958      22.962
# RM_tric_imp_std        4.4162      0.353     12.521      0.000       3.722       5.110
# LSTAT_tric_imp_std    -3.0341      0.432     -7.016      0.000      -3.885      -2.184
# TAX_tric_imp_std      -2.2597      0.690     -3.274      0.001      -3.617      -0.902
# RAD_tric_imp_std       1.0428      0.817      1.276      0.203      -0.564       2.650
# CRIM_tric_imp_std     -1.3540      0.701     -1.931      0.054      -2.733       0.025
# NOX_tric_imp_std      -0.3905      0.480     -0.813      0.417      -1.335       0.554
# DIS_tric_imp_std      -1.7095      0.412     -4.150      0.000      -2.520      -0.899
# ==============================================================================
# Omnibus:                       53.469   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.732
# Skew:                           0.954   Prob(JB):                     4.86e-18
# Kurtosis:                       4.329   Cond. No.                         8.57
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mod = sm.OLS(y_train, sm.add_constant(X_train[['RM_tric_imp_std',
                               'LSTAT_tric_imp_std',
                               #'PTRATIO_tric_imp',
                               'TAX_tric_imp_std',
                               'RAD_tric_imp_std',
                               'CRIM_tric_imp_std',
                               #'NOX_tric_imp_std',
                               #'B_tric_imp',
                               'DIS_tric_imp_std']]))
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.732
# Model:                            OLS   Adj. R-squared:                  0.727
# Method:                 Least Squares   F-statistic:                     157.7
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):           5.99e-96
# Time:                        01:37:52   Log-Likelihood:                -1054.1
# No. Observations:                 354   AIC:                             2122.
# Df Residuals:                     347   BIC:                             2149.
# Df Model:                           6
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 22.4605      0.255     88.038      0.000      21.959      22.962
# RM_tric_imp_std        4.4245      0.352     12.556      0.000       3.731       5.118
# LSTAT_tric_imp_std    -3.0743      0.429     -7.159      0.000      -3.919      -2.230
# TAX_tric_imp_std      -2.3811      0.674     -3.535      0.000      -3.706      -1.056
# RAD_tric_imp_std       1.1017      0.814      1.354      0.177      -0.498       2.702
# CRIM_tric_imp_std     -1.4219      0.696     -2.043      0.042      -2.791      -0.053
# DIS_tric_imp_std      -1.4977      0.319     -4.697      0.000      -2.125      -0.871
# ==============================================================================
# Omnibus:                       54.468   Durbin-Watson:                   2.113
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               82.271
# Skew:                           0.962   Prob(JB):                     1.36e-18
# Kurtosis:                       4.371   Cond. No.                         7.81
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mod = sm.OLS(y_train, sm.add_constant(X_train[['RM_tric_imp_std',
                               'LSTAT_tric_imp_std',
                               #'PTRATIO_tric_imp',
                               'TAX_tric_imp_std',
                               #'RAD_tric_imp_std',
                               'CRIM_tric_imp_std',
                               #'NOX_tric_imp_std',
                               #'B_tric_imp',
                               'DIS_tric_imp_std']]))
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.730
# Model:                            OLS   Adj. R-squared:                  0.726
# Method:                 Least Squares   F-statistic:                     188.5
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):           1.03e-96
# Time:                        01:38:05   Log-Likelihood:                -1055.0
# No. Observations:                 354   AIC:                             2122.
# Df Residuals:                     348   BIC:                             2145.
# Df Model:                           5
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# const                 22.4605      0.255     87.933      0.000      21.958      22.963
# RM_tric_imp_std        4.4488      0.352     12.626      0.000       3.756       5.142
# LSTAT_tric_imp_std    -3.1571      0.426     -7.419      0.000      -3.994      -2.320
# TAX_tric_imp_std      -1.7991      0.519     -3.465      0.001      -2.820      -0.778
# CRIM_tric_imp_std     -0.8460      0.552     -1.534      0.126      -1.931       0.239
# DIS_tric_imp_std      -1.4560      0.318     -4.582      0.000      -2.081      -0.831
# ==============================================================================
# Omnibus:                       53.160   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               79.707
# Skew:                           0.945   Prob(JB):                     4.92e-18
# Kurtosis:                       4.354   Cond. No.                         4.98
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %%
mod = sm.OLS(y_train, sm.add_constant(X_train[['RM_tric_imp_std',
                               #'LSTAT_tric_imp_std',
                               #'PTRATIO_tric_imp',
                               'TAX_tric_imp_std'
                               #'RAD_tric_imp_std',
                               #'CRIM_tric_imp_std',
                               #'NOX_tric_imp_std',
                               #'B_tric_imp',
                               #'DIS_tric_imp_std'
                               ]]))
res = mod.fit()
print(res.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                   MEDV   R-squared:                       0.673
# Model:                            OLS   Adj. R-squared:                  0.671
# Method:                 Least Squares   F-statistic:                     360.8
# Date:                Sat, 24 Sep 2022   Prob (F-statistic):           7.18e-86
# Time:                        01:40:43   Log-Likelihood:                -1089.2
# No. Observations:                 354   AIC:                             2184.
# Df Residuals:                     351   BIC:                             2196.
# Df Model:                           2
# Covariance Type:            nonrobust
# ====================================================================================
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               22.4605      0.280     80.174      0.000      21.909      23.011
# RM_tric_imp_std      6.0901      0.295     20.670      0.000       5.511       6.670
# TAX_tric_imp_std    -2.9526      0.295    -10.021      0.000      -3.532      -2.373
# ==============================================================================
# Omnibus:                       62.951   Durbin-Watson:                   2.096
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              148.154
# Skew:                           0.883   Prob(JB):                     6.74e-33
# Kurtosis:                       5.632   Cond. No.                         1.37
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# /usr/local/lib/python3.7/dist-packages/statsmodels/tsa/tsatools.py:142: FutureWarning: In a future version of pandas all arguments of concat except for the argument 'objs' will be keyword-only
#   x = pd.concat(x[::order], 1)

# %% [markdown]
# * <b>crim : </b> Tasa de criminalidad per cápita por ciudad.
#
# * <b>rm : </b>Número medio de habitaciones por vivienda.
#
# * <b>dis : </b>Media ponderada de las distancias a cinco centros de empleo de Boston.
#
# * <b>ptratio : </b>Proporción alumno-profesor por ciudad.
#
# * <b>lstat : </b>Estatus más bajo de la población (porcentaje).
#
# * <b>black : </b> 1000 (Bk - 0.63) ^ 2 donde Bk es la proporción de negros por ciudad.

# %%
X_train[['RM_tric_imp_std',
                               'LSTAT_tric_imp_std',
                               #'PTRATIO_tric_imp',
                               'TAX_tric_imp_std',
                               #'RAD_tric_imp_std',
                               #'CRIM_tric_imp_std',
                               #'NOX_tric_imp_std',
                               #'B_tric_imp',
                               'DIS_tric_imp_std']].corr()
# Out:
#                     RM_tric_imp_std  LSTAT_tric_imp_std  TAX_tric_imp_std  \
# RM_tric_imp_std            1.000000           -0.660009         -0.305581
# LSTAT_tric_imp_std        -0.660009            1.000000          0.524796
# TAX_tric_imp_std          -0.305581            0.524796          1.000000
# DIS_tric_imp_std           0.219239           -0.493149         -0.504073
#
#                     DIS_tric_imp_std
# RM_tric_imp_std             0.219239
# LSTAT_tric_imp_std         -0.493149
# TAX_tric_imp_std           -0.504073
# DIS_tric_imp_std            1.000000
